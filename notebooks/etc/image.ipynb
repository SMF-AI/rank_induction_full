# %%
from camelyon.data_models import Patches
patches = Patches.from_patch_h5("/vast/AI_team/dataset/CAMELYON16/patch/20x_h5/train/M/tumor_001.h5")

# %%
from matplotlib import pyplot as plt
plt.imshow(patches[150].image_array)

# %%
from camelyon.networks.resnet50 import ResNetBackbone
model = ResNetBackbone()
model.eval()
# Out:
# ResNetBackbone(
#   (stem): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
# ...

# %%
patches = Patches.from_feature_h5("/vast/AI_team/dataset/CAMELYON16/feature/resnet50_3rd_20x_h5/train/M/tumor_001.h5")
# Out:
# Patch(image_shape=None, path=None, label=None, coordinates=Coordinates(x_min=44800, y_min=74368, x_max=45248, y_max=74816), address=(100, 166), confidences=None)

# %%
patches[0].feature
# Out:
# tensor([ 0.0000, 37.2530, 10.1009,  ..., 43.8057,  4.9599,  2.7271])
